# %% [markdown]
# <a href="https://colab.research.google.com/github/nabdeep-patel/Bcas-du/blob/main/Level1_Task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Virtual Internship at Cognifyz Technologies.**
#
# ---
#
#
# #### **By Nabdeep Patel | Data Science and Artificial Intelligence**
# [Linkedin](https://www.linkedin.com/in/nabdeeppatel) | [Github](https://www.github.com/nabdeep-patel) | [Website](https://nabdeep-patel.github.io/portfolio) | [Email](mailto:nabdeeppatel@gmail.com)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **Introduction**
# ---
# It involves loading all the prerequisite libraries along with importing the dataset from google drive link

# %% [markdown]
# Loading the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %% [markdown]
# Importing the google dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/drive/MyDrive/Assignment/Cognify Tech/Copy of Dataset .csv")

# %% [markdown]
# ## **LEVEL 1 (*TASK 1*): Data Exploration and Preprocessing**
#
#
# ---
#
#
#
# 1.   Explore the dataset and identify the number
# of rows and columns.
#
# 2. Check for missing values in each column and
# handle them accordingly.
#
# 3. Perform data type conversion if necessary.
# Analyze the distribution of the target variable
# ("Aggregate rating") and identify any class
# imbalances.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %% [markdown]
# Displaying the number of rows and columns and the name of each column

# %%
x, y = df.shape
print("No of rows: ", x)
print("No of columns: ", y)
# Out:
# No of rows:  9551
# No of columns:  21

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %% [markdown]
# Identifying and removing the null values

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %% [markdown]
# As the null values is in only one column `Cusines`, which contains text values and the number of null values is `9` much less than the total number of rows `9551`. So removing them by `dropna()`function.

# %%
df = df.dropna()

# %% [markdown]
# The number of rows and columns after removing the null values

# %%
x, y = df.shape
print("No of rows: ", x)
print("No of columns: ", y)
# Out:
# No of rows:  9542
# No of columns:  21

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %% [markdown]
# Converting the datatype of columns with float values to int for better understanding of the data

# %%
df.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# dtype: object

# %%
df["Aggregate rating"] = df["Aggregate rating"].astype('int')
# Out:
# <ipython-input-12-08ca84da230f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Aggregate rating"] = df["Aggregate rating"].astype('int')

# %% [markdown]
# Converting the datatype of the columns with string values to category for better understanding of the data

# %%
df.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating          int64
# Rating color             object
# Rating text              object
# Votes                     int64
# dtype: object

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Aggregate rating'], bins=20, kde=True)
plt.title('Distribution of Aggregate Rating')
plt.xlabel('Aggregate Rating')
plt.ylabel('Frequency')
plt.show()

# %%
print(df["Aggregate rating"].value_counts())
# Out:
# Aggregate rating
# 3    4583
# 0    2148
# 2    1430
# 4    1378
# 1       3
# Name: count, dtype: int64

# %%
imbalance_ratio = df["Aggregate rating"].value_counts().max() / df["Aggregate rating"].value_counts().min()
print("Imbalance ratio:")
print(imbalance_ratio)
# Out:
# Imbalance ratio:
# 1527.6666666666667
